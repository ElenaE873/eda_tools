# %%
import seaborn as sns

# %% [markdown]
# #### All of these examples are examples of relationships between two variables

# %% [markdown]
# #### Scatter plot

# %% [markdown]
# Is one column influeced by another?

# %%
sns.scatterplot(df['column_1'], df['column_2'])

# %% [markdown]
# Observe what kind of relationship there is in the scatterplot between the two columns

# %% [markdown]
# ##### Regression line of a plot

# %%
sns.regplot(df['column_1'], df['column_2'])

# %% [markdown]
# ##### Box Plot

# %% [markdown]
# Taking a column that has categories of values (ex. branch A, B, C) and looking to determine what the min/max and mean against another column is (ex. gross income)

# %%
sns.boxplot(x=df['Branch'], y=df['Gross Income'])

# %% [markdown]
# This way you can look to see how the gross income compares across the different branches

# %% [markdown]
# You can even look at something like the relationship between Gender and Income

# %% [markdown]
# #### With this plot you can also obsver the values at the 25 and 75 percentiles

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In this image you can see at the 75% percentile (top line) women spend more than men, but on average they're pretty close

# %% [markdown]
# #### You can even just plot in the x-axis and it will be horizonal

# %%
sns.boxplot(x = df['column_1'])

# %% [markdown]
# #### Line Plot

# %% [markdown]
# ##### Is there a noticeable TIME TREND in a variable

# %% [markdown]
# ** For this type of graph you need unique dates. Therefore if you have multiple entries for a date, you must aggregate the data at the unique dates.**

# %%
df.grouby(df.index).mean().index
#grouping by the index of the dataframe, with each value at the date level representing the mean of that column

# %%
sns.lineplot(x=df.grouby(df.index).mean().index, 
             y=df.grouby(df.index).mean()['Gross Income'])

# %% [markdown]
# #### Pair-Plot

# %% [markdown]
# Plotting for every combination off your data set

# %%
sns.pairplot(df)
