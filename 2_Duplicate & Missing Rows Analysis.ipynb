# %%
df.duplicate()

# %% [markdown]
# ##### Index and Boolean of the duplicate rows that are duplicated

# %%
df.duplicate().sum()

# %% [markdown]
# ##### Give you the number of rows that are duplicated

# %% [markdown]
# ##### If you want to see where/what the duplicate rows are

# %%
df[df.duplicated() == True]

# %% [markdown]
# ##### To drop the duplicated values

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ##### Total number of missing columsn per column

# %%
df.isna().sum()

# %% [markdown]
# ##### The ratio of the missing

# %%
df.isna().sum()/len(df)

# %% [markdown]
# ##### Visualize the missing values by the seaborn map

# %%
sns.heatmap(df.isull())

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Without the color bar

# %%
sns.heatmap(df.isull(), cbar=False)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### To fill in the missing values with ZERO

# %%
df.fillna(df.mean(), inplace=True) #to make sure you modify the dataset so that it keeps it

# %% [markdown]
# Note: The missing values are replaced with the mean only for NUMERIC values

# %% [markdown]
# ##### For CATEGORICAL VALUES:

# %% [markdown]
# You can take the "mode" and replace the mode for all the missing categorical columsn

# %%
df.mode().iloc[0] #here you can observe the mode for each column

# %%
df.fillna(df.mode.iloc[0], inplace=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Note: The more black, the less missing values -- all black; no missing values

# %% [markdown]
# ##### Eliminating rows that have missinv data

# %%
df_2 = df_1.dropna() #drop of all the rows that have missing data

# %%
df_2 = df_1.dropna(1) #drops any of the columns that has missing data
